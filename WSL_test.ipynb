# %%
WLS <- read.csv("WLS.csv")
summary(WLS)
# Out:
#       X                 X.1                X.2                X.3
#  Length:10318       Length:10318       Length:10318       Length:10318
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#      X.4                X.5                X.6                X.7
#  Length:10318       Length:10318       Length:10318       Length:10318
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#      X.8                X.9                X.10               X.11
#  Length:10318       Length:10318       Length:10318       Length:10318
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#      X.12               X.13               X.14               X.15
# ...

# %%
WLS[WLS == 0] <- NA
WLS[WLS == ""] <- NA
WLS[WLS < 0] <- NA
WLS$deatyr <- replace(WLS$deatyr, which(WLS$deatyr > 9000), NA)
WLS
# Out:
# Error in `$<-.data.frame`(`*tmp*`, deatyr, value = logical(0)): replacement has 0 rows, data has 10318
# Traceback:
#
# 1. `$<-`(`*tmp*`, deatyr, value = logical(0))
# 2. `$<-.data.frame`(`*tmp*`, deatyr, value = logical(0))
# 3. stop(sprintf(ngettext(N, "replacement has %d row, data has %d",
#  .     "replacement has %d rows, data has %d"), N, nrows), domain = NA)
